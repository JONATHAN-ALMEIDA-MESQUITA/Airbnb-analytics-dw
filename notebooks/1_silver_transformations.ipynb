# %% [markdown]
# <h1 style="text-align: center;">🥈Transformação de dados da camada bronze para silver</h1>

# %% [markdown]
# <img src="Imagem_projeto.png" alt="Visualização do Projeto" width="600" style="display: block; margin-left: auto; margin-right: auto;"/>

# %% [markdown]
# **📄 Transformações padrão**
#
# + Valores Nulos;
#     - Padronizar valores nulos que foram carregados como **("NaN", "nan", "None", "none", "NULL", "null", "")**
#
# + Higienização simples de strings:
#     - Remover sujeiras como espaços extras, quebras de linha e caracteres de controle invisíveis
#
# + Analise de IDs duplicados;
#     - Verificação simples de IDs que podem estar duplicados na camada bronze e caso esteja, sera mantido apenas o ultimo id com base no scrape_id ou ultima data

# %%
#📦import das principais libs


import pandas as pd
import numpy as np
import re
from typing import List, Optional, Sequence
import psycopg2
from psycopg2.extras import execute_values
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv
import geopandas as gpd
from shapely.geometry import Point
from urllib.parse import urlparse

# %%
#import das variaveis de ambiente
load_dotenv(r"..\scripts\.env")


#conexao com postgres
try:
    DB_URI = (f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}")


    engine = create_engine(DB_URI)
    conn = engine.connect()
    raw_conn = engine.raw_connection()
    print("✅ Conexao realizada com sucesso!")
except Exception as e:
    print(f"❌ Erro ao conectar ao banco de dados {e}")
# Out:
# ✅ Conexao realizada com sucesso!

# %% [markdown]
# ### **Tratamento tabela T_DIM_ANUNCIO**

# %%
#Leitura da tabela Anuncio
df_anuncio = pd.read_sql('SELECT * FROM a_bronze. "T_DIM_ANUNCIO"', conn)
df_anuncio.head(3)
# Out:
#    id_anuncio                         listing_url       scrape_id  \
# 0       14063  https://www.airbnb.com/rooms/14063  20180414160018
# 1       17878  https://www.airbnb.com/rooms/17878  20180414160018
# 2       24480  https://www.airbnb.com/rooms/24480  20180414160018
#
#                                 name  \
# 0               Living in a Postcard
# 1  Very Nice 2Br - Copacabana - WiFi
# 2   Nice and cozy near Ipanema Beach
#
#                                              summary  \
# 0  Besides the most iconic's view, our apartment ...
# 1  Please note that special rates apply for New Y...
# 2  My studio is located in the best  of Ipanema. ...
#
#                                                space  \
# 0                                                NaN
# 1  - large balcony which looks out on pedestrian ...
# 2  The studio is located at Vinicius de Moraes St...
#
#                                          description experiences_offered  \
# 0  Besides the most iconic's view, our apartment ...                none
# 1  Please note that special rates apply for New Y...                none
# 2  My studio is located in the best  of Ipanema. ...                none
#
#                                neighborhood_overview  \
# 0  Best and favorite neighborhood of Rio. Perfect...
# 1  This is the best spot in Rio. Everything happe...
# 2  The beach, the lagoon, Ipanema is a great loca...
#
#                                                notes  \
# 0                                                NaN
# 1                                                NaN
# 2  O prédio é bastante simples , mas o apartament...
#
#                                              transit  \
# 0  Everything is there. METRO is 5 min walk.  Dir...
# 1  Excellent location. Close to all major public ...
# 2                                                NaN
#
#                                               access  \
# 0                                                NaN
# 1  The entire apartment is yours. It is a vacatio...
# 2  From the International airport, take a  regula...
#
#                                          interaction  \
# 0                                                NaN
# 1  I will be available throughout your stay shoul...
# 2  Os hóspedes podem perguntar por email suas que...
#
#                                          house_rules  \
# 0  strictly no smoking in the apartment ! We want...
# 1  Please leave the apartment in a clean fashion ...
# 2  Please remove sand when you come from the beac...
#
#                                          picture_url
# 0  https://a0.muscache.com/im/pictures/66421/ae9b...
# 1  https://a0.muscache.com/im/pictures/65320518/3...
# 2  https://a0.muscache.com/im/pictures/11955612/b...

# %%
#Analise de formato de colunas
df_anuncio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70185 entries, 0 to 70184
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_anuncio             70185 non-null  int64
#  1   listing_url            70185 non-null  object
#  2   scrape_id              70185 non-null  int64
#  3   name                   70185 non-null  object
#  4   summary                70185 non-null  object
#  5   space                  70185 non-null  object
#  6   description            70185 non-null  object
#  7   experiences_offered    70185 non-null  object
#  8   neighborhood_overview  70185 non-null  object
#  9   notes                  70185 non-null  object
#  10  transit                70185 non-null  object
#  11  access                 70185 non-null  object
#  12  interaction            70185 non-null  object
#  13  house_rules            70185 non-null  object
#  14  picture_url            70185 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 8.0+ MB

# %%
#Tratamento de valores nulos
valores_nulos = ["NaN", "nan", "None", "none", "NULL", "null", ""]

contagem_nulos = df_anuncio.apply(lambda col: col.isnull().sum() + col.isin(valores_nulos).sum())

#Criando df para avaliar o percentual de valores nulos por coluna.
nulos_anuncio = pd.DataFrame({
    "colunas" : contagem_nulos.index,
    "total_nulos": contagem_nulos.values,
    "%nulos" : (contagem_nulos.values / len(df_anuncio) * 100).round(2).astype(str) + "%"
})

nulos_anuncio
# Out:
#                   colunas  total_nulos  %nulos
# 0              id_anuncio            0    0.0%
# 1             listing_url            0    0.0%
# 2               scrape_id            0    0.0%
# 3                    name           83   0.12%
# 4                 summary         4943   7.04%
# 5                   space        30096  42.88%
# 6             description         3031   4.32%
# 7     experiences_offered        70185  100.0%
# 8   neighborhood_overview        34418  49.04%
# 9                   notes        51079  72.78%
# 10                transit        35199  50.15%
# 11                 access        41041  58.48%
# 12            interaction        38873  55.39%
# 13            house_rules        36941  52.63%
# 14            picture_url            0    0.0%

# %% [markdown]
# #### Notas tabela Anuncio:
#
# + Colunas com mais de 60% de valores nulo serão removidos da camada Silver.
# + Padronizar urls dos anuncios
# + Padronizar strings
# + Criar colunas de auditoria

# %% [markdown]
# #### Aplicar transformações da tabela "T_DIM_ANUNCIO" e ETL para o banco na camada silver

# %%
#Copia do df para padronização
df = df_anuncio.copy()

#1) Padronização dos valores nulos
valores_nulos = ["NaN", "nan", "None", "none", "NULL", "null", ""]
colunas = df.select_dtypes(include="object").columns
for c in colunas:
    df[c] = df[c].replace(list(valores_nulos), np.nan)


#2) Higienização simples de strings
def clean_text(s):
    if not isinstance(s, str): return s
    s = s.strip()
    s = re.sub(r"\s+", " ", s) # colapsa espacos 
    s = "".join(ch for ch in s if ch >= " ") #Remover caracteres de controle \n \t etc..
    return s 

for c in colunas:
    df[c] = df[c].map(clean_text)


#4) Remover colunas >60% de valores nulos
null_ratio = df.isnull().mean()
to_drop = null_ratio[null_ratio >= 0.6].index.to_list()
df = df.drop(columns=to_drop, errors='ignore')


#5) Verificação de IDs duplicados e remoção do ultimo scraped_id

df = (df
      .sort_values(['id_anuncio', 'scrape_id'], ascending=[True, False])
      .drop_duplicates(subset=['id_anuncio'], keep='first'))


#6) validação de URL
def is_valid_url(u):
    if not isinstance(u, str) or not u: return False
    try:
        p = urlparse(u)
        return bool(p.scheme and p.netloc)
    except:
        return False
    
for ucol in ["listing_url","picture_url"]:
    if ucol in df.columns:
        df.loc[~df[ucol].map(is_valid_url), ucol] = np.nan


#7) Auditoria
df["fonte"] = 'Airbnb_bronze'
df['dt_ingestao'] = pd.Timestamp.utcnow()


#8) df com os ajustes realizados "Pronto para inserir no banco"


df_anuncio_silver = df.copy()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17276\3782966486.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[c] = df[c].replace(list(valores_nulos), np.nan)

# %%
df_anuncio_silver
# Out:
#        id_anuncio                            listing_url       scrape_id  \
# 0           14063     https://www.airbnb.com/rooms/14063  20180414160018
# 1           17878     https://www.airbnb.com/rooms/17878  20180414160018
# 49801       21280     https://www.airbnb.com/rooms/21280  20200420135919
# 2           24480     https://www.airbnb.com/rooms/24480  20180414160018
# 3           25026     https://www.airbnb.com/rooms/25026  20180414160018
# ...           ...                                    ...             ...
# 68584    43514675  https://www.airbnb.com/rooms/43514675  20200524171540
# 68585    43515526  https://www.airbnb.com/rooms/43515526  20200524171540
# 68586    43517044  https://www.airbnb.com/rooms/43517044  20200524171540
# 68587    43522964  https://www.airbnb.com/rooms/43522964  20200524171540
# 68588    43524785  https://www.airbnb.com/rooms/43524785  20200524171540
#
#                                             name  \
# 0                           Living in a Postcard
# 1              Very Nice 2Br - Copacabana - WiFi
# 49801           Renovated Modern Apt. Near Beach
# 2               Nice and cozy near Ipanema Beach
# 3      Beautiful Modern Decorated Studio in Copa
# ...                                          ...
# 68584                           Quarto no Leblon
# 68585      Lindo Apartamento, 2 quadras da praia
# 68586    Conforto e concentração pra sua estadia
# 68587                                Botafogo ll
# 68588       QUARTÃO EM COPACABANA, DIAS ou MESES
#
#                                                  summary  \
# 0      Besides the most iconic's view, our apartment ...
# 1      Please note that special rates apply for New Y...
# 49801  Immaculately renovated top-floor apartment ove...
# 2      My studio is located in the best of Ipanema. T...
# 3      Our apartment is a little gem, everyone loves ...
# ...                                                  ...
# 68584  Meu apartamento é simples e muito aconchegante...
# 68585                                                NaN
# 68586                                                NaN
# 68587  Excelente apartamento 2 quartos e dois banheir...
# 68588  QUARTO AMPLO E AREJADO, CORAÇÃO DE COPACABANA ...
#
#                                                    space  \
# 0                                                    NaN
# 1      - large balcony which looks out on pedestrian ...
# 49801  Immaculately renovated top-floor apartment in ...
# 2      The studio is located at Vinicius de Moraes St...
# 3      This newly renovated studio (last renovations ...
# ...                                                  ...
# 68584                                                NaN
# 68585                                                NaN
# 68586                                                NaN
# 68587                                                NaN
# 68588  Está Localizado na Rua Principal de Copacabana...
#
#                                              description  \
# 0      Besides the most iconic's view, our apartment ...
# 1      Please note that special rates apply for New Y...
# 49801  Immaculately renovated top-floor apartment ove...
# 2      My studio is located in the best of Ipanema. T...
# 3      Our apartment is a little gem, everyone loves ...
# ...                                                  ...
# 68584  Meu apartamento é simples e muito aconchegante...
# 68585                                                NaN
# 68586                                                NaN
# 68587  Excelente apartamento 2 quartos e dois banheir...
# 68588  QUARTO AMPLO E AREJADO, CORAÇÃO DE COPACABANA ...
#
#                                    neighborhood_overview  \
# 0      Best and favorite neighborhood of Rio. Perfect...
# 1      This is the best spot in Rio. Everything happe...
# 49801  This is the best neighborhood in Zona Sul. For...
# 2      The beach, the lagoon, Ipanema is a great loca...
# 3      Copacabana is a lively neighborhood and the ap...
# ...                                                  ...
# 68584                                                NaN
# 68585                                                NaN
# 68586                                                NaN
# 68587                                                NaN
# 68588  COPACABANA É LINDA E COMPLETA EM TUDO, TUDO O ...
#
#                                                  transit  \
# 0      Everything is there. METRO is 5 min walk. Dire...
# 1      Excellent location. Close to all major public ...
# 49801  The new metro station is just a few steps away...
# 2                                                    NaN
# 3      At night we recommend you to take taxis only. ...
# ...                                                  ...
# 68584                                                NaN
# 68585                                                NaN
# 68586                                                NaN
# 68587                                                NaN
# 68588  Situado a Apenas 02 Ruas do Metrô, Apenas 02 R...
#
#                                                   access  \
# 0                                                    NaN
# 1      The entire apartment is yours. It is a vacatio...
# 49801  This is an older "Art Deco" style building, so...
# 2      From the International airport, take a regular...
# 3      internet wi-fi, cable tv, air cond, ceiling fa...
# ...                                                  ...
# 68584                                                NaN
# 68585                                                NaN
# 68586                                                NaN
# 68587                                                NaN
# 68588                                                NaN
#
#                                              interaction  \
# 0                                                    NaN
# 1      I will be available throughout your stay shoul...
# 49801  Someone will be there at check in and check ou...
# 2      Os hóspedes podem perguntar por email suas que...
# 3      Only at check in, we like to leave our guests ...
# ...                                                  ...
# 68584                                                NaN
# 68585                                                NaN
# 68586                                                NaN
# 68587                                                NaN
# 68588                          Estou sempre a Disposição
#
#                                              house_rules  \
# 0      strictly no smoking in the apartment ! We want...
# 1      Please leave the apartment in a clean fashion ...
# 49801  This is a booking agreement for rental of a tw...
# 2      Please remove sand when you come from the beac...
# 3      Smoking outside only. Family building so pleas...
# ...                                                  ...
# 68584                                                NaN
# 68585                                                NaN
# 68586                                                NaN
# 68587                                                NaN
# 68588                                                NaN
#
#                                              picture_url          fonte  \
# 0      https://a0.muscache.com/im/pictures/66421/ae9b...  Airbnb_bronze
# 1      https://a0.muscache.com/im/pictures/65320518/3...  Airbnb_bronze
# 49801  https://a0.muscache.com/im/pictures/60851312/b...  Airbnb_bronze
# 2      https://a0.muscache.com/im/pictures/11955612/b...  Airbnb_bronze
# 3      https://a0.muscache.com/im/pictures/3003965/68...  Airbnb_bronze
# ...                                                  ...            ...
# 68584  https://a0.muscache.com/im/pictures/74ed68fe-b...  Airbnb_bronze
# 68585  https://a0.muscache.com/im/pictures/3dce639d-a...  Airbnb_bronze
# 68586  https://a0.muscache.com/im/pictures/80589a65-9...  Airbnb_bronze
# 68587  https://a0.muscache.com/im/pictures/b0703b26-2...  Airbnb_bronze
# 68588  https://a0.muscache.com/im/pictures/fd70c6ca-f...  Airbnb_bronze
#
#                            dt_ingestao
# 0     2025-08-17 21:58:12.064897+00:00
# 1     2025-08-17 21:58:12.064897+00:00
# 49801 2025-08-17 21:58:12.064897+00:00
# 2     2025-08-17 21:58:12.064897+00:00
# 3     2025-08-17 21:58:12.064897+00:00
# ...                                ...
# 68584 2025-08-17 21:58:12.064897+00:00
# 68585 2025-08-17 21:58:12.064897+00:00
# 68586 2025-08-17 21:58:12.064897+00:00
# 68587 2025-08-17 21:58:12.064897+00:00
# 68588 2025-08-17 21:58:12.064897+00:00
#
# [70185 rows x 15 columns]

# %% [markdown]
# #### Realizar carga no banco da tabela b_silver."T_DIM_ANUNCIO"

# %%
#ETL PARA TABELA SILVER

def _ensure_columns(df: pd.DataFrame, target_cols: Sequence[str]) -> pd.DataFrame:
    """Garante que o DF tenha todas as colunas do contrato e na ordem correta."""
    for c in target_cols:
        if c not in df.columns:
            df[c] = np.nan
    return df[list(target_cols)].copy()


def _nan_to_none_records(df: pd.DataFrame) -> List[tuple]:
    """Converte NaN -> None (NULL no Postgres) e retorna lista de tuplas linha-a-linha."""
    records = []
    for row in df.itertuples(index=False, name=None):
        # transforma cada valor NaN em None
        fixed = tuple(None if (isinstance(x, float) and np.isnan(x)) else x for x in row)
        records.append(fixed)
    return records


def upsert_df(
    conn,
    df: pd.DataFrame,
    schema: str,
    table: str,
    target_cols: Sequence[str],
    conflict_cols: Sequence[str],
    update_cols: Optional[Sequence[str]] = None,
    page_size: int = 10000,
):
    """
    Faz UPSERT de um DF para uma tabela Postgres.
    - target_cols: colunas na ordem do contrato (iguais à tabela).
    - conflict_cols: colunas da UNIQUE/PK usadas no ON CONFLICT.
    - update_cols: quais colunas atualizar em caso de conflito.
      (por padrão, todas as target_cols EXCETO as de conflito).
    """
    if not len(df):
        return  # nada a fazer

    # 1) Garante contrato (colunas + ordem)
    df_up = _ensure_columns(df, target_cols)

    # 2) Define colunas a atualizar no DO UPDATE
    if update_cols is None:
        update_cols = [c for c in target_cols if c not in conflict_cols]
    if not update_cols:
        # Se não sobrou nada para atualizar, faça DO NOTHING para evitar erro
        on_conflict_sql = f'ON CONFLICT ({", ".join(f"""\"{c}\"""" for c in conflict_cols)}) DO NOTHING'
    else:
        set_sql = ", ".join(f'"{c}"=EXCLUDED."{c}"' for c in update_cols)
        on_conflict_sql = (
            f'ON CONFLICT ({", ".join(f"""\"{c}\"""" for c in conflict_cols)}) DO UPDATE SET {set_sql}'
        )

    # 3) Monta o INSERT com placeholder %s (execute_values preenche em lote)
    cols_sql = ", ".join(f'"{c}"' for c in target_cols)
    sql = f'INSERT INTO {schema}."{table}" ({cols_sql}) VALUES %s {on_conflict_sql};'

    # 4) Converte NaN->None e envia em lotes
    records = _nan_to_none_records(df_up)
    with conn.cursor() as cur:
        execute_values(cur, sql, records, page_size=page_size)
    conn.commit()

# %%
TARGET_COLS = [
    "id_anuncio","listing_url","scrape_id","name","summary","space","description",
    "neighborhood_overview","transit","access","interaction","house_rules",
    "picture_url","fonte","dt_ingestao"
]


upsert_df(
    conn=raw_conn,  
    df=df_anuncio_silver,
    schema="b_silver",
    table="T_DIM_ANUNCIO",
    target_cols=TARGET_COLS,
    conflict_cols=["id_anuncio"],   # chave de UPSERT (PK/UNIQUE)
    # update_cols=None  -> atualiza todas as colunas exceto a de conflito (default)
    page_size=10000
)
print("✅ T_DIM_ANUNCIO carregada/atualizada no Silver.")
# Out:
# ✅ T_DIM_ANUNCIO carregada/atualizada no Silver.

# %% [markdown]
# ### **Tratamento tabela T_DIM_ANFITRIAO**

# %%
#leitura da tabela anfitrião

df_anfitriao = pd.read_sql('SELECT * FROM  a_bronze. "T_DIM_ANFITRIAO"', conn)
df_anfitriao.head(3)
# Out:
#    host_id  fk_anuncio                                 host_url host_name  \
# 0    53598       14063  https://www.airbnb.com/users/show/53598    Shalev
# 1    68997       17878  https://www.airbnb.com/users/show/68997  Matthias
# 2    99249       24480  https://www.airbnb.com/users/show/99249      Goya
#
#    host_since                           host_location  \
# 0  2009-11-12                                      FL
# 1  2010-01-08  Rio de Janeiro, Rio de Janeiro, Brazil
# 2  2010-03-26  Rio de Janeiro, Rio de Janeiro, Brazil
#
#                                           host_about host_response_time  \
# 0  Hello , my name is Shalev , I am an orchestra ...                NaN
# 1  I used to work as a journalist all around the ...     within an hour
# 2   Welcome to Rio!\r\nI am a filmmaker and a tea...     within an hour
#
#   host_response_rate host_is_superhost  \
# 0                NaN                 f
# 1               100%                 t
# 2               100%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/53598/profile...
# 1  https://a0.muscache.com/im/pictures/67b13cea-8...
# 2  https://a0.muscache.com/im/pictures/6b40475c-2...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/53598/profile...           Botafogo
# 1  https://a0.muscache.com/im/pictures/67b13cea-8...         Copacabana
# 2  https://a0.muscache.com/im/pictures/6b40475c-2...            Ipanema
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  2.0                        2.0
# 2                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0             ['email', 'phone', 'reviews', 'jumio']                    t
# 1                      ['email', 'phone', 'reviews']                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified
# 0                      t
# 1                      f
# 2                      t

# %% [markdown]
# ##### Analise inicial, tipo de dados, valores nulos, novas features.

# %%
df_anfitriao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43180 entries, 0 to 43179
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_id                    43180 non-null  int64
#  1   fk_anuncio                 43180 non-null  int64
#  2   host_url                   43180 non-null  object
#  3   host_name                  43180 non-null  object
#  4   host_since                 43147 non-null  object
#  5   host_location              43180 non-null  object
#  6   host_about                 43180 non-null  object
#  7   host_response_time         43180 non-null  object
#  8   host_response_rate         43180 non-null  object
#  9   host_is_superhost          43180 non-null  object
#  10  host_thumbnail_url         43180 non-null  object
#  11  host_picture_url           43180 non-null  object
#  12  host_neighbourhood         43180 non-null  object
#  13  host_listings_count        43147 non-null  float64
#  14  host_total_listings_count  43147 non-null  float64
#  15  host_verifications         43180 non-null  object
#  16  host_has_profile_pic       43180 non-null  object
#  17  host_identity_verified     43180 non-null  object
# dtypes: float64(2), int64(2), object(14)
# memory usage: 5.9+ MB

# %%
#Tratamento de valores nulos
valores_nulos = ["NaN", "nan", "None", "none", "NULL", "null", ""]

contagem_nulos = df_anfitriao.apply(lambda col: col.isnull().sum() + col.isin(valores_nulos).sum())

#Criando df para avaliar o percentual de valores nulos por coluna.
nulos_anfitriao = pd.DataFrame({
    "colunas" : contagem_nulos.index,
    "total_nulos": contagem_nulos.values,
    "%nulos" : (contagem_nulos.values / len(df_anfitriao) * 100).round(2).astype(str) + "%"
})
nulos_anfitriao
# Out:
#                       colunas  total_nulos  %nulos
# 0                     host_id            0    0.0%
# 1                  fk_anuncio            0    0.0%
# 2                    host_url            0    0.0%
# 3                   host_name           33   0.08%
# 4                  host_since           33   0.08%
# 5               host_location          332   0.77%
# 6                  host_about        27467  63.61%
# 7          host_response_time        19886  46.05%
# 8          host_response_rate        19886  46.05%
# 9           host_is_superhost           33   0.08%
# 10         host_thumbnail_url           33   0.08%
# 11           host_picture_url           33   0.08%
# 12         host_neighbourhood        20241  46.88%
# 13        host_listings_count           33   0.08%
# 14  host_total_listings_count           33   0.08%
# 15         host_verifications           33   0.08%
# 16       host_has_profile_pic           33   0.08%
# 17     host_identity_verified           33   0.08%

# %%
df_anfitriao['host_total_listings_count'].sort_values(ascending=False)
# Out:
# 38681    1495.0
# 42570     336.0
# 38634     327.0
# 38636     325.0
# 38633     313.0
#           ...
# 28037       NaN
# 28825       NaN
# 40584       NaN
# 40996       NaN
# 41908       NaN
# Name: host_total_listings_count, Length: 43180, dtype: float64

# %%
# contagem por host_id
dup_counts = df_anfitriao.groupby("host_id").size().sort_values(ascending=False)

n_hosts = dup_counts.shape[0]
n_rows  = len(df_anfitriao)
n_dups  = (dup_counts > 1).sum()

print(f"linhas={n_rows:,}  hosts únicos={n_hosts:,}  hosts com duplicata={n_dups:,}")
dup_counts[dup_counts > 1].head(10)
# Out:
# linhas=43,180  hosts únicos=43,180  hosts com duplicata=0
# Series([], dtype: int64)

# %% [markdown]
# #### Notas:
# + Coluna **host_since**         : Esta como obj mas é data
# + Coluna **host_response_rate** : Esta como obj mas é uma coluna de percentual
# + Coluna **host_about**         : Sera exluida por ter mais de 60% de valores nulos e nao ter muita relevancia para o contesto de analise
# + Coluna **host_listings_count**: Esta como float porem é uma coluna que recebe valores interios, **(Sera necessario arrumar o tipo de dados no banco)**
# + Coluna **host_total_listings_count** : Esta como float porem é uma coluna que recebe valores interios
# + Colunas **"host_is_superhost","host_has_profile_pic","host_identity_verified"**, transformar t/f em True e False

# %%
#Copia do df para padronização
df = df_anfitriao.copy()

#1) Padronização dos valores nulos
valores_nulos = ["NaN", "nan", "None", "none", "NULL", "null", ""]
colunas = df.select_dtypes(include="object").columns
for c in colunas:
    df[c] = df[c].replace(list(valores_nulos), np.nan)


#2) Higienização simples de strings
def clean_text(s):
    if not isinstance(s, str): return s
    s = s.strip()
    s = re.sub(r"\s+", " ", s) # colapsa espacos 
    s = "".join(ch for ch in s if ch >= " ") #Remover caracteres de controle \n \t etc..
    return s 

for c in colunas:
    df[c] = df[c].map(clean_text)


#4) Remover colunas >60% de valores nulos
null_ratio = df.isnull().mean()
to_drop = null_ratio[null_ratio >= 0.6].index.to_list()
df = df.drop(columns=to_drop, errors='ignore')



#5)transformar coluna obj em data
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')
df['host_since'] = df['host_since'].apply(lambda x: x.to_pydatetime() if pd.notnull(x) else None)
df['host_since'] = df['host_since'].fillna(pd.Timestamp("1900-01-01"))


#6)Tratar strings dentro da coluna host_response_rate (%) e tranformar strinsgs de valores nulos para 0 e manter o dado em proporcao
df['host_response_rate'] = (df['host_response_rate']
                                      .astype(str)
                                      .str.strip()
                                      .str.replace('%','', regex=False)
                                      .replace(valores_nulos, 0)
                                      .astype(float)
                                      )/100


#7) Correção de dados das coluna host_listings_count e host_total_listings_count de float para inteiro

fltcolumns = ['host_listings_count', 'host_total_listings_count']

for col in fltcolumns:
    df[col] = (pd.to_numeric(df[col], errors='coerce')
                         .fillna(0)
                         .astype(int)
                         )

#8) Transformar booleanas t/f em True e False
bool_map = {"t": True, "f": False, True: True, False: False}
for c in ["host_is_superhost","host_has_profile_pic","host_identity_verified"]:
    if c in df.columns:
        df[c] = df[c].map(bool_map).astype("bool")




#9) Padronizar categorias
map_resp_time = {
    "within an hour":"within an hour",
    "within a few hours":"within a few hours",
    "within a day":"within a day",
    "a few days or more":"a few days or more"
}
df["host_response_time"] = df["host_response_time"].str.strip().str.lower().map(map_resp_time)



#10) Padronizar Urls
for ucol in ["host_url","host_picture_url","host_thumbnail_url"]:
    if ucol in df.columns:
        df.loc[~df[ucol].map(is_valid_url), ucol] = np.nan


#11)host_verifications: transformar string/lista-serializada em array “limpo” (se vier como texto tipo ['email','phone'])

import ast
def parse_verifs(v):
    if isinstance(v, list): return v
    if not isinstance(v, str) or not v.strip(): return None
    try:
        x = ast.literal_eval(v)
        if isinstance(x, list):
            return [str(i).strip().lower() for i in x]
    except:
        pass
    return None

df["host_verifications"] = df["host_verifications"].apply(parse_verifs)


#12) Auditoria
df["fonte"] = 'Airbnb_bronze'
df['dt_ingestao'] = pd.Timestamp.utcnow()



#13) df com os ajustes realizados "Pronto para inserir no banco"
df_anfitriao_silver = df.copy()

# %% [markdown]
# #### Realizar carga no banco da tabela b_silver."T_ANFITRIAO"

# %%
TARGET_COLS = ['host_id', 'host_url', 'host_name', 'host_since',
       'host_location', 'host_response_time', 'host_response_rate',
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
       'host_neighbourhood', 'host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'fonte',
       'dt_ingestao'
]


upsert_df(
    conn=raw_conn,  
    df=df_anfitriao_silver,
    schema="b_silver",
    table="T_DIM_ANFITRIAO",
    target_cols=TARGET_COLS,
    conflict_cols=["host_id"],   # chave de UPSERT (PK/UNIQUE)
    # update_cols=None  -> atualiza todas as colunas exceto a de conflito (default)
    page_size=10000
)
print("✅ T_DIM_ANUNCIO carregada/atualizada no Silver.")
# Out:
# ✅ T_DIM_ANUNCIO carregada/atualizada no Silver.

# %% [markdown]
# ### **Tratamento tabela T_DIM_LOCALIZACAO**

# %%
#leitura tabela localização

df_localizacao = pd.read_sql('SELECT * FROM a_bronze. "T_DIM_LOCALIZACAO"', conn)
df_localizacao.head()
# Out:
#    id_localizacao  fk_anuncio                                  street  \
# 0               1       14063              Rio de Janeiro, RJ, Brazil
# 1               2       17878  Rio de Janeiro, Rio de Janeiro, Brazil
# 2               3       24480  Rio de Janeiro, Rio de Janeiro, Brazil
# 3               4       25026  Rio de Janeiro, Rio de Janeiro, Brazil
# 4               5       31560              Rio de Janeiro, RJ, Brazil
#
#   neighbourhood neighbourhood_cleansed            city           state  \
# 0      Botafogo               Botafogo  Rio de Janeiro              RJ
# 1    Copacabana             Copacabana  Rio de Janeiro  Rio de Janeiro
# 2       Ipanema                Ipanema  Rio de Janeiro  Rio de Janeiro
# 3    Copacabana             Copacabana  Rio de Janeiro  Rio de Janeiro
# 4       Ipanema                Ipanema  Rio de Janeiro              RJ
#
#      zipcode          market          smart_location country_code country  \
# 0  22250-040  Rio De Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 1  22020-050  Rio De Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 2  22411-010  Rio De Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 3  22060-020  Rio De Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 4  22410-003  Rio De Janeiro  Rio de Janeiro, Brazil           BR  Brazil
#
#     latitude  longitude is_location_exact
# 0 -22.946854 -43.182737                 t
# 1 -22.965919 -43.178962                 t
# 2 -22.985698 -43.201935                 t
# 3 -22.977117 -43.190454                 t
# 4 -22.983024 -43.214270                 t

# %%
df_localizacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 902210 entries, 0 to 902209
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id_localizacao          902210 non-null  int64
#  1   fk_anuncio              902210 non-null  int64
#  2   street                  902210 non-null  object
#  3   neighbourhood           902210 non-null  object
#  4   neighbourhood_cleansed  902210 non-null  object
#  5   city                    902210 non-null  object
#  6   state                   902210 non-null  object
#  7   zipcode                 902210 non-null  object
#  8   market                  902210 non-null  object
#  9   smart_location          902210 non-null  object
#  10  country_code            902210 non-null  object
#  11  country                 902210 non-null  object
#  12  latitude                902210 non-null  float64
#  13  longitude               902210 non-null  float64
#  14  is_location_exact       902210 non-null  object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 103.2+ MB

# %%
#Analise padronização dos dados 
print(df_localizacao['smart_location'].unique())
print("-"*60)
print(df_localizacao['market'].unique())
print("-"*60)
print(df_localizacao['country_code'].unique())
print("-"*60)
print(df_localizacao['city'].unique())
# Out:
# ['Rio de Janeiro, Brazil' 'Rio, Brazil' 'Joatinga, Brazil'
#  'Copacabana, Brazil' 'Rio de janeiro , Brazil' 'Rio De Janeiro, Brazil'
#  'Itanhangá, Brazil' 'Barra da Tijuca, Brazil' 'Glória, Brazil'
#  'Jacarepagua, Brazil' 'Pitangueiras, Brazil' 'Ipanema, Brazil'
#  'Estácio, Brazil' 'Vidigal, Brazil' 'Santa Teresa, Brazil'
#  'Santa Tereza, Brazil' 'Jardim Botanico , Brazil'
#  'Rio de janeiro, Brazil' 'Leblon, Brazil' 'Lagoa, Brazil'
#  'Rio de Janeiro / Copacabana , Brazil' 'RJ, Brazil' 'Urca, Brazil'
#  'Tijuca, Brazil' 'Rio de Janeiro - 22440-000, Brazil'
#  'angra dos reis, Brazil' 'Rio de Janeiro -IPANEMA, Brazil'
#  'Copacabana, Rio de Janeiro , Brazil'
#  'Rio de Janeiro - Laranjeiras, Brazil' 'Riode Janeiro, Brazil'
#  ' Copacabana, Brazil' 'Rio, Copacabana, Brazil' 'Rio de Janeiro , Brazil'
#  'Vila Isabel, Brazil' 'Catete, Brazil' 'Vargem Grande, Brazil'
#  'Leblon, Rio de Janeiro, Brazil' 'Centro, Brazil' 'Rj, Brazil'
#  'リオ・デ・ジャネイロ, Brazil' 'Colegio, Brazil' 'São Conrado, Brazil'
#  'Andarai, Brazil' 'Ipanema, Rio de Janeiro, Brazil'
#  ' Rio de Janeiro, Brazil' 'Rio - Grajaú, Brazil'
#  'Jardim Botânico, Brazil' 'Maracanã, Brazil'
#  'Rio e Janeiro - Barra da Tijuca, Brazil' 'Barra, Brazil'
#  'Rio Ipanema, Brazil'
#  'Rio - Vila Pan Americana - Barra da Tijuca, Brazil' 'Flamengo, Brazil'
#  'rio de janeiro, Brazil' 'Rio de janeiro, bairro tijuca, Brazil'
#  'Rio de Janeiro-RJ, Brazil' 'Río de Janeiro, Brazil' 'Madureira, Brazil'
#  'Copacabana- RJ, Brazil' 'Pechincha, Jacarepagua, Rio de Janeiro, Brazil'
#  'tijuca, Brazil' 'barra de Guaratiba, Brazil' 'RIO DE JANEIRO, Brazil'
#  'Copacabana, Rio de Janeiro, Brazil' 'Copacabana , Brazil'
#  'Barra de Guaratiba, Brazil' 'Barra Da Tijuca, Brazil'
#  'Rio de Janeiro/RJ, Brazil' 'Ipanema, Rio, Brazil'
#  'Rio de Janeiro, Rio de Janeiro, Brazil'
#  'Terreirão, Recreio dos Bandeirantes , Brazil' 'Vila isabel, Brazil'
#  'Botafogo, Brazil' 'Araruama , Brazil' 'Leme, Brazil'
#  'Gavea -Rio de Janeiro, Brazil' 'Recreio dos Bandeirantes, Brazil'
#  'Ipanema - Rio de Janeiro, Brazil' 'Gávea, Brazil' 'Catumbi, Brazil'
#  'Rio de Janeiro - Copacabana, Brazil' 'Laranjeiras, Brazil'
#  'Campo Grande, Brazil' 'RJ - Lapa / Cores da Lapa, Brazil'
#  'cabo frio, Brazil' 'Rio de Janeiro,, Brazil' 'NILOPOLIS, Brazil'
#  'Taquara, Brazil' 'Rio de Janeiro - Vargem Grande, Brazil'
#  'Barra da Tijuca, Rio de Janeiro, Brazil'
#  'Rio de Janeiro - Barra da Tijuca, Brazil' 'Armação dos búzios, Brazil'
#  'Fonte da Saudade, Lagoa, Brazil' 'BR, Brazil' 'Grajau, Brazil'
#  'Portuguesa, Brazil' 'Duque de Caxias, Brazil' 'salvador, Brazil'
#  'Petropolis, Brazil' 'RJ , Brazil' 'Rj , Brazil' 'Santa Tertesa, Brazil'
#  'Vargem Pequena , Brazil' 'Paquetá, Brazil' 'copacabana, Brazil'
#  'State of Rio de Janeiro, Brazil'
#  'Recreio dos Bandeirantes, Rio de Janeiro, Brazil' 'Recreio, Brazil'
#  'Rio de Janeiro - Ipanema, Brazil' 'Barra da Tijuca  , Brazil'
#  'Centro / Lapa - Rio de Janeiro, Brazil'
#  'Rio de Janeiro, Recreio dos Bandeirantes, Brazil'
#  'Campo grande RJ, Brazil' 'Rio de Janeiro\n, Brazil'
#  'Rio Comprido, Brazil' 'Centro , Brazil' 'Ilha de Guaratiba, Brazil'
#  'Rio de Janeiroeiro, Brazil' 'barra da tijuca, Brazil'
#  'Jardim Guanabara, Brazil' 'Barra da Tijuca , Brazil'
#  'Rio de Janeiro / Ipanema, Brazil' 'rio de Janeiro\n\n\n\n, Brazil'
#  'Rio de Janeiro/Barra da tijuca, Brazil' 'Flamengo , Brazil'
#  'Del Castilho, Brazil' 'BARRA DA TIJUCA Rio de Janeiro, Brazil'
#  'Engenho de Dentro , Brazil' 'Anil, Brazil' 'vargem grande, Brazil'
#  'Sampaio, Brazil' 'Rio de Janeiro - Taquara, Brazil' 'Anchieta, Brazil'
#  'Ilha de Paquetá, Brazil' 'Guaratiba, Brazil' 'Jardim Paraíso, Brazil'
#  'Barra da tijuca , Brazil' 'Vila isabel , Brazil' 'Vaz Lobo, Brazil'
#  'Joá, Brazil' 'centro lapa , Brazil' 'Rio de Janeiro, BR, Brazil'
#  '⚑ Botafogo, Brazil' 'Rio de Janeiro, Rio de Janeiro, BR, Brazil'
#  'Copacabana Rio de Janeiro, Brazil' 'Ilha do Governador , Brazil'
#  'Angra dos Reis , Brazil' 'leme, Brazil' 'Nova Friburgo, Brazil'
#  'Vila Valqueire, Brazil' 'Leblon , Brazil' 'vila isabel , Brazil'
#  '里约热内卢, Brazil' 'Olinda, Brazil' 'Maricá, Brazil'
#  'Rio de Janeiro condomínio Minha praia, Brazil'
#  'Barra da Tijuca , Península, Rio de Janeiro, Brazil'
#  'Ilha do governador, Brazil' 'Bonsucesso, Brazil'
#  'Gávea, Rio de Janeiro, Brazil' 'Gardênia Azul, Brazil'
#  'São João de Meriti, Brazil' 'Rio de Janeiro- edifício UP LIFE , Brazil'
#  'Río de Janeiro, Rio de Janeiro, BR, Brazil' 'São Cristóvão, Brazil'
#  'Freguesia (Jacarepaguá), Brazil' 'Rio de Janeiro, Brasil, Brazil'
#  'Recreio dos Bandeirantes - Rio de Janeiro-  BR, Brazil'
#  'Ipanema , Brazil' 'Recreio dos Bandeirantes - RJ., Brazil'
#  'Recreio dos , Brazil' 'RJ/RJ/, Brazil' 'rio de janeiro , Brazil'
#  'Estrada do Rio Morto, 500, Vargem Grande, Rio de Janeiro , Brazil'
#  'Leme, Rio de Janeiro, Brazil' 'Recreio dos Bandeirantes , Brazil'
#  'Copacabana,Rio de Janeiro, Brazil' 'Petrópolis, Brazil'
#  'Centro - Rio de Janeiro, Brazil' 'Capacabana, Brazil' 'ipanema, Brazil'
#  'Rio de Janeiro, Alto Leblon, Brazil' 'Pechincha, Brazil'
#  'RIO de janeiro, Brazil' 'rio de Janeiro , Brazil' 'Maricá , Brazil'
#  'Copacabana/Rio de Janeiro, Brazil' 'Cosme Velho, Brazil'
#  'Tijuca, Rio de Janeiro, Brazil' 'rio de Janeiro, Brazil'
#  'Rio de janeiro-Rj, Brazil' 'Rio de Janeiro, RJ, Brasil, Brazil'
#  'rj, Brazil' 'Rio.de.Janeiro, Brazil'
#  'Rio de Janeiro Barra da tijuca, Brazil' 'Curicica, Brazil'
#  'Rio de Janriro, Brazil' 'Santa Teresa , Brazil' 'Santos, Brazil'
#  'Barra de Guaratiba, RJ, Brazil'
#  'rio de janeiro ,\ncentro rio de janeiro\nrio de janeiro\n\nrio de janeiro, Brazil'
#  'Catete , Brazil' 'Rio de janeiro centro, Lapa, Brazil'
#  'Rio de Janeiro / Rocinha, Brazil' 'Lapa Rio de janeiro, Brazil'
#  'Paciência, Brazil' 'Recreio dos Bandeirantes / Rio de Janeiro, Brazil'
#  'Ilha da Gigoia - Barra da Tijuca- Rio de Janeiro, Brazil'
#  'Jacarepaguá , Brazil' 'Rio de ja, Brazil' 'Irajá, Brazil'
#  'ilha da Gigoia-  Barra da Tijuca -Rio de Janeiro, Brazil'
#  'Buzios, Brazil' 'Рио-де-Жанейро, Brazil' 'rio, Brazil' 'humaita, Brazil'
#  'Tijuca, rio de janeiro , Brazil' 'Between Leblon and Vidigal, Brazil'
#  'Rii de janeiro, Brazil' 'Praca da Bandeira, Brazil' 'Saúde, Brazil'
#  'Tauá, Brazil' 'Pedra de Guaratiba, Brazil' 'Humaitá, Brazil'
#  'Sepetiba, Brazil' 'Rio de , Brazil' 'Freguesia (Ilha), Brazil'
#  'Bangu, Brazil' 'Camorim, Brazil' 'Santa Cruz, Brazil' 'Usina, Brazil'
#  'Caju, Brazil' 'Piedade, Brazil' 'Vargem Pequena, Brazil'
#  'Cidade Nova, Brazil' 'Penha Circular, Brazil' 'Cosmos, Brazil'
#  'Lins de Vasconcelos, Brazil' 'Engenho Novo, Brazil'
#  'RIo de Janeiro, Brazil' 'Santíssimo, Brazil' 'Vista Alegre, Brazil'
#  'Riachuelo, Brazil' 'Parque Anchieta, Brazil' 'Parada de Lucas, Brazil'
#  'Inhauma, Brazil' 'Jardim Sulacap, Brazil' 'R. Bandeirantes, Brazil'
#  'Higienópolis, Brazil' 'São Conrado , Brazil' 'Maria da Graça, Brazil'
#  'Santo Cristo, Brazil' 'Recreio dos Bandeirantes - Rj, Brazil'
#  'Rocha, Brazil' 'Freguesia - Jacarépaguá, Brazil'
#  'Quintino Bocaiuva, Brazil' 'Jacarepaguá, Brazil' 'Gambôa, Brazil'
#  'São Francisco Xavie, Brazil' 'Praça Seca, Brazil'
#  'Cidade de Deus, Brazil' 'Penha, Brazil' 'Praia de Boiçucanga, Brazil'
#  'Tanque, Brazil' 'Alto da Boa Vista, Brazil'
#  'Esplanada do Cruzeiro, Brazil' 'Bairro de Fátima, Brazil'
#  'Campinho, Brazil' 'Ribeira, Brazil' 'Abolição, Brazil'
#  'Jd Botanico, Brazil' 'Padre Miguel, Brazil' 'Benfica, Brazil'
#  'B Tijuca, Brazil' 'Engenho de Dentro, Brazil' 'Vila da Penha, Brazil'
#  'Alto Leblon/ Chácara do Céu, Brazil'
#  'Rio de Janeiro Ilha do governador , Brazil' 'Rcr Bandeirantes, Brazil'
#  'Barra Guaratiba, Brazil' 'Bráz De Pina, Brazil'
#  'RJ Jardim Guanabara, Brazil' 'Meier, Brazil' 'Recreio/RJ, Brazil'
#  'Todos os Santos, Brazil' 'Freguesia (Ilha do Governador), Brazil'
#  'Copacabvana, Brazil' 'Rio de Janeiro, Rio de Janeiro, , Brazil'
#  'Praia do Recreio dos Bandeirantes, Brazil' 'Jardim Carioca, Brazil'
#  'Água Santa, Brazil' 'Gloria, Brazil' 'Pca da Bandeira, Brazil'
#  'Complexo do Alemão, Brazil' 'Tijuca/RJ, Brazil'
#  'São Francisco Xavier, Brazil' 'Campo Belo, Brazil'
#  'Honório Gurgel, Brazil' 'Redentor, Brazil' 'Vasco da Gama, Brazil'
#  'Recreio Bandeirante, Brazil' 'Realengo, Brazil' 'De Fátima, Brazil'
#  'Grumari, Brazil' 'Olaria, Brazil' 'Rio De Janeiro, Antarctica'
#  'Cachambi, Brazil' 'Vila Cosmos, Brazil' 'Inhoaíba, Brazil'
#  'Praia da Bandeira, Brazil' 'Bento Ribeiro, Brazil'
#  'Rio De Janeiro, Andorra' 'Vicente de Carvalh, Brazil' 'IPANEMA, Brazil'
#  'Riocentro, Brazil' 'Rio de Janeiro - Leblon, Brazil'
#  'Edifício ALONE Bairro: Copacabana, Brazil'
#  'Rio de Janeiro, Ipanema, Brazil' 'Rio De Janeiro,, Brazil'
#  'Copacabana - Rio de Janeiro, Brazil' 'Araras, Rio de Janeiro, Brazil'
#  'Barra da Tijuca - Rio de Janeiro, Brazil'
#  'Município do Rio de Janeiro -Buzios , Brazil' 'Niterói, Brazil'
#  'Cabo Frio , Brazil' 'Ipanema\nIpanema, Brazil' 'realengo, Brazil'
#  'Mangueira, Brazil' 'Vicente de Carvalho, Brazil'
#  'Angra dos Reis, Brazil' 'Copacabana / RJ, Brazil' 'Rio Janeiro, Brazil'
#  'Guadalupe, Brazil' 'Cascadura, Brazil' 'Freguesia Jacarepagua, Brazil'
#  'Praia do Pontal de Sernambetiba, Brazil' 'Encantado, Brazil'
#  'Parque Sao Nicolau, Brazil' 'Camaçari , Brazil'
#  'Ilha do Governador, Brazil' '1º etapa, Brazil'
#  ' COPACABANA- Rio de Janeiro , Brazil' 'Cocotá, Brazil'
#  'Oswaldo Cruz, Brazil' 'Cacuia, Brazil' 'Rocha Miranda, Brazil'
#  'Ramos, Brazil' 'Ilha das Cobras, Brazil' 'Pilares, Brazil'
#  'Rec dos Bandeirante, Brazil' 'Copacaban, Brazil'
#  'Recreio dos Bandeir, Brazil' 'Copacapana, Brazil'
#  'Río de janeiro , Brazil' 'Copacabana/RJ, Brazil' 'Inhoaiba, Brazil'
#  'Cidade Universitária, Brazil' 'Mangaratiba , Brazil'
#  'Balneário Barra do Sul, Brazil' 'Barra da tijuca, Brazil'
#  'Barra de Guaratiba , Brazil' 'Taquara - Jpa., Brazil'
#  'Rio de Jameiro, Brazil' 'Praia de Maresias, Brazil'
#  'R. dos Bandeirantes, Brazil' 'Pc Bandeira, Brazil'
#  'Río de Janeiro , Brazil' 'Higüey , Dominica' 'Engenho da Rainha, Brazil'
#  'Marechal Hermes, Brazil' 'Rocinha, Brazil' 'Váz Lobo, Brazil'
#  'Copacabana - LEME, Brazil' 'RIO DE JANEIRO , Brazil'
#  'Copacabana - RJ, Brazil' 'Recreio dos Bandeirantes - RJ, Brazil'
#  'Cordovil, Brazil' 'Paraty, Brazil' 'Barra Grande , Brazil'
#  'Cabo Frio, Brazil' 'Vila Militar, Brazil'
#  'Joatinga, Rio de Janeiro, Brazil' 'Teresopolis, Brazil'
#  'São Francisco, Brazil' 'Senador Vasconcelos, Brazil'
#  'Tamoios Cabo Frio, Brazil' 'Copacabana /Rio de Janeiro, Brazil'
#  'Galeão, Brazil' 'Senador Camará, Brazil' 'São Paulo, Brazil'
#  'Praia de Águas Belas, Brazil' 'Guapimirim, Brazil' 'Lapa, Brazil'
#  'Pavuna, Brazil' 'Bancários, Brazil' 'Caldas Novas , Brazil'
#  'Piuma, Brazil' 'Barros Filho, Brazil' 'Costa Barros, Brazil'
#  'Lins de Vasconcelo, Brazil' 'Jacarepagua Freguesia , Brazil'
#  'Ri, Brazil' 'Rio de Janeiro Barra da Tijuca, Brazil'
#  'Botafogo - Rio de Janeiro, Brazil' 'Andaraí, Brazil' 'Maré, Brazil'
#  'Glória / Santa Teresa, Brazil' 'Rio de Janeiro / Copacabana, Brazil'
#  'CopaCabana, Brazil'
#  'Teresopolis - Vargem Grande - Rio de Janeiro Brasil, Brazil'
#  'Copacabana, RJ, Brazil' 'Flamengo Rio de Janeiro, Brazil'
#  'Vargem Grande, Rio de Janeiro , Brazil' 'Nova Iguaçu, Brazil'
#  'Engenheiro Leal, Brazil' 'I. Governador, Brazil'
#  'Jardim America, Brazil' 'Jacarépagua, Brazil' 'Vigário Geral, Brazil'
#  'Deodoro, Brazil' 'Manguinhos, Brazil' 'Brás de Pina, Brazil'
#  'Méier, Brazil' 'Bairro Botafogo, Brazil'
#  'Rio de Janeiro, Copacabana, Brazil' 'R dos Bandeirantes, Brazil'
#  'Bertioga, Brazil' 'Serrinha do Alambari , Brazil'
#  'Freguesia de Jacarepaguá, Brazil' 'COPACABANA, Brazil'
#  'Glória/centro , Brazil' 'Rio de Janeio, Brazil'
#  'Arraial do Cabo, Brazil' 'Grajaú, Brazil' 'Coelho Neto, Brazil'
#  'Tomás Coelho, Brazil' 'São Conrado / Joa , Brazil'
#  'Rios de Janeiro, Brazil' 'Santo Antônio, Brazil' 'Itacoatiara, Brazil'
#  'Jardim Pero, Brazil' 'Foguete, Brazil' 'Gloria , Brazil'
#  'Praia Grossa, Brazil' 'Caborê, Brazil' 'Itaipava , Brazil'
#  'Botafogo , Brazil' 'Gamboa, Brazil' 'Colégio, Brazil'
#  'Rio  de Janeiro, Brazil' 'Jacaré, Brazil' 'Cajueiro, Brazil'
#  'Recreio dos Bandeirantes - Rio de Janeiro , Brazil'
#  'Pr Ferradura, Brazil' 'Ilha Primeira, Brazil' 'Guapemirim, Brazil'
#  'Areal, Brazil' 'Village da Ferradura, Brazil' 'V Carvalho, Brazil'
#  'Praia Linda, Brazil' 'Taquara Jacarepaguá-RJ, Brazil' 'Sítio, Brazil'
#  'Rio de ianeiro , Brazil' 'Acari, Brazil' 'E, Brazil'
#  'Alta floresta , Brazil' 'Rio  de janeiro, Brazil'
#  'Rio de  Janeiro , Brazil' 'Mury, Brazil' 'Rio de Janeieo, Brazil'
#  'Ricardo de Albuquerque, Brazil'
#  'Cidade Universitária da Universidade Federal do Rio de Janeiro, Brazil'
#  'Moneró, Brazil' 'Centro, Bairro de Fátima, Brazil' 'Recreiio, Brazil'
#  'Copacabana, Rio de Janeiro, RJ, Brazil' 'Fazenda Velha, Brazil'
#  'Rio Centro , Brazil' 'Praia de Guaratiba , Brazil'
#  'Praça da Bandeira, Brazil' 'Domingos Martins, Brazil'
#  'Freguesia, Brazil' 'Cidade Industrial, Brazil'
#  'Rio de Janeiro RJ, Brazil' 'Rio De Janeiro – Rj, Brazil'
#  'Recreio Bendeirante, Brazil' 'Recreio dos Bande, Brazil'
#  'Praia da Urca, Brazil' 'city, Brazil' ' Barra da Tijuca, Brazil'
#  'Vila Canaa, Brazil' 'Vila Aparecida, Brazil' 'Jardim Excelcior, Brazil'
#  'rRio de Janeiro, Brazil' 'Rio de Janeiro Angra dos Reis , Brazil'
#  'Riio De Janeiro, Brazil' 'Maracanã , Brazil'
#  'Armação dos Búzios, Brazil' 'Balneário Camboriú , Brazil'
#  'Nilópolis, Brazil' 'R, Brazil' 'Taquara , Brazil'
#  'Copacabana Rio de Janeiro , Brazil' 'leblon, Brazil'
#  'Petrópolis , Brazil' 'Bom jardim, Brazil'
#  'Río de Janeiro Copacabana , Brazil' 'COPACABANA , Brazil'
#  'Jardim Esperança, Brazil' 'CENTR0, Brazil' 'Quintino Bocaiúva, Brazil'
#  'Itaipava, Brazil' 'Magalhães Bastos, Brazil'
#  'Praia de Jericoacoara , Brazil' 'Parque Analândia, Brazil'
#  'Jandira, Brazil' 'Juiz de fora, Brazil' 'Campo dos Afonsos, Brazil'
#  'Parque Juriti, Brazil' 'Hi, Brazil' 'Duque De Caxias, Brazil'
#  'Cabedelo, Brazil' 'Guaramiranga, Brazil' 'Praia Grande , Brazil'
#  'Cinelândia, Brazil' 'Rio de Janeior, Brazil' 'Villa de buzios,, Brazil'
#  'Mucugê , Brazil' 'joatinga, Brazil' 'Jardim do Mar, Brazil'
#  'Jardim Del Rey, Brazil' 'Terra Nova Uberlândia 1, Brazil'
#  'Vila Assunção, Brazil' 'Santana, Brazil' 'Miguel Couto, Brazil'
#  'Vila Sao Guilherme, Brazil' 'Copacabana, Rio de Janeiro, BR, Brazil']
# ------------------------------------------------------------
# ['Rio De Janeiro' 'Other (International)' 'Buzios' 'Angra dos Reis'
#  'Sao Paulo' 'Salvador' 'Armacao De Buzios' 'Brasilia' 'Rome' 'Perth'
#  'Manchester' 'NaN' 'Rio de Janeiro' 'Regiao Serrana RJ']
# ------------------------------------------------------------
# ['BR' 'AQ' 'AD' 'DM']
# ------------------------------------------------------------
# ['Rio de Janeiro' 'Rio' 'Joatinga' 'Copacabana' 'Rio de janeiro '
#  'Rio De Janeiro' 'Itanhangá' 'Barra da Tijuca' 'Glória' 'Jacarepagua'
#  'Pitangueiras' 'Ipanema' 'Estácio' 'Vidigal' 'Santa Teresa'
#  'Santa Tereza' 'Jardim Botanico ' 'Rio de janeiro' 'Leblon' 'Lagoa'
#  'Rio de Janeiro / Copacabana ' 'NaN' 'Urca' 'Tijuca' 'RJ'
#  'Rio de Janeiro - 22440-000' 'angra dos reis' 'Rio de Janeiro -IPANEMA'
#  'Copacabana, Rio de Janeiro ' 'Rio de Janeiro - Laranjeiras'
#  'Riode Janeiro' ' Copacabana' 'Rio, Copacabana' 'Rio de Janeiro '
#  'Vila Isabel' 'Catete' 'Vargem Grande' 'Leblon, Rio de Janeiro' 'Centro'
#  'Rj' 'リオ・デ・ジャネイロ' 'Colegio' 'São Conrado' 'Andarai'
#  'Ipanema, Rio de Janeiro' ' Rio de Janeiro' 'Rio - Grajaú'
#  'Jardim Botânico' 'Maracanã' 'Rio e Janeiro - Barra da Tijuca' 'Barra'
#  'Rio Ipanema' 'Rio - Vila Pan Americana - Barra da Tijuca' 'Flamengo'
#  'rio de janeiro' 'Rio de janeiro, bairro tijuca' 'Rio de Janeiro-RJ'
#  'Río de Janeiro' 'Madureira' 'Copacabana- RJ'
#  'Pechincha, Jacarepagua, Rio de Janeiro' 'tijuca' 'barra de Guaratiba'
#  'RIO DE JANEIRO' 'Copacabana, Rio de Janeiro' 'Copacabana '
#  'Barra de Guaratiba' 'Barra Da Tijuca' 'Rio de Janeiro/RJ' 'Ipanema, Rio'
#  'Rio de Janeiro, Rio de Janeiro' 'Terreirão, Recreio dos Bandeirantes '
#  'Vila isabel' 'Botafogo' 'Araruama ' 'Leme' 'Gavea -Rio de Janeiro'
#  'Recreio dos Bandeirantes' 'Ipanema - Rio de Janeiro' 'Gávea' 'Catumbi'
#  'Rio de Janeiro - Copacabana' 'Laranjeiras' 'Campo Grande'
#  'RJ - Lapa / Cores da Lapa' 'cabo frio' 'Rio de Janeiro,' 'NILOPOLIS'
#  'Taquara' 'Rio de Janeiro - Vargem Grande'
#  'Barra da Tijuca, Rio de Janeiro' 'Rio de Janeiro - Barra da Tijuca'
#  'Armação dos búzios' 'Fonte da Saudade, Lagoa' 'Grajau' 'Portuguesa'
#  'Duque de Caxias' 'salvador' 'Petropolis' 'RJ ' 'Rj ' 'Santa Tertesa'
#  'Vargem Pequena ' 'Paquetá' 'copacabana'
#  'Recreio dos Bandeirantes, Rio de Janeiro' 'Recreio'
#  'Rio de Janeiro - Ipanema' 'Barra da Tijuca  '
#  'Centro / Lapa - Rio de Janeiro'
#  'Rio de Janeiro, Recreio dos Bandeirantes' 'Campo grande RJ'
#  'Rio de Janeiro\n' 'Rio Comprido' 'Centro ' 'Ilha de Guaratiba'
#  'Rio de Janeiroeiro' 'barra da tijuca' 'Jardim Guanabara'
#  'Barra da Tijuca ' 'Rio de Janeiro / Ipanema' 'rio de Janeiro\n\n\n\n'
#  'Rio de Janeiro/Barra da tijuca' 'Flamengo ' 'Del Castilho'
#  'BARRA DA TIJUCA Rio de Janeiro' 'Engenho de Dentro ' 'Anil'
#  'vargem grande' 'Sampaio' 'Rio de Janeiro - Taquara' 'Anchieta'
#  'Ilha de Paquetá' 'Guaratiba' 'Jardim Paraíso' 'Barra da tijuca '
#  'Vila isabel ' 'Vaz Lobo' 'Joá' 'centro lapa ' 'Rio de Janeiro, BR'
#  '⚑ Botafogo' 'Rio de Janeiro, Rio de Janeiro, BR'
#  'Copacabana Rio de Janeiro' 'Ilha do Governador ' 'Angra dos Reis '
#  'leme' 'Nova Friburgo' 'Vila Valqueire' 'Leblon ' 'vila isabel ' '里约热内卢'
#  'Olinda' 'Maricá' 'Rio de Janeiro condomínio Minha praia'
#  'Barra da Tijuca , Península, Rio de Janeiro' 'Ilha do governador'
#  'Bonsucesso' 'Gávea, Rio de Janeiro' 'Gardênia Azul' 'São João de Meriti'
#  'Rio de Janeiro- edifício UP LIFE ' 'Río de Janeiro, Rio de Janeiro, BR'
#  'São Cristóvão' 'Freguesia (Jacarepaguá)' 'Rio de Janeiro, Brasil'
#  'Recreio dos Bandeirantes - Rio de Janeiro-  BR' 'Ipanema '
#  'Recreio dos Bandeirantes - RJ.' 'Recreio dos ' 'RJ/RJ/'
#  'rio de janeiro '
#  'Estrada do Rio Morto, 500, Vargem Grande, Rio de Janeiro '
#  'Leme, Rio de Janeiro' 'Recreio dos Bandeirantes '
#  'Copacabana,Rio de Janeiro' 'Petrópolis' 'Centro - Rio de Janeiro'
#  'Capacabana' 'ipanema' 'Rio de Janeiro, Alto Leblon' 'Pechincha'
#  'RIO de janeiro' 'rio de Janeiro ' 'Maricá ' 'Copacabana/Rio de Janeiro'
#  'Cosme Velho' 'Tijuca, Rio de Janeiro' 'rio de Janeiro'
#  'Rio de janeiro-Rj' 'Rio de Janeiro, RJ, Brasil' 'rj' 'Rio.de.Janeiro'
#  'Rio de Janeiro Barra da tijuca' 'Curicica' 'Rio de Janriro'
#  'Santa Teresa ' 'Santos' 'Barra de Guaratiba, RJ'
#  'rio de janeiro ,\ncentro rio de janeiro\nrio de janeiro\n\nrio de janeiro'
#  'Catete ' 'Rio de janeiro centro, Lapa' 'Rio de Janeiro / Rocinha'
#  'Lapa Rio de janeiro' 'Paciência'
#  'Recreio dos Bandeirantes / Rio de Janeiro'
#  'Ilha da Gigoia - Barra da Tijuca- Rio de Janeiro' 'Jacarepaguá '
#  'Rio de ja' 'Irajá' 'ilha da Gigoia-  Barra da Tijuca -Rio de Janeiro'
#  'Buzios' 'Рио-де-Жанейро' 'rio' 'humaita' 'Tijuca, rio de janeiro '
#  'Between Leblon and Vidigal' 'Rii de janeiro' 'Praca da Bandeira' 'Saúde'
#  'Tauá' 'Pedra de Guaratiba' 'Humaitá' 'Sepetiba' 'Rio de '
#  'Freguesia (Ilha)' 'Bangu' 'Camorim' 'Santa Cruz' 'Usina' 'Caju'
#  'Piedade' 'Vargem Pequena' 'Cidade Nova' 'Penha Circular' 'Cosmos'
#  'Lins de Vasconcelos' 'Engenho Novo' 'RIo de Janeiro' 'Santíssimo'
#  'Vista Alegre' 'Riachuelo' 'Parque Anchieta' 'Parada de Lucas' 'Inhauma'
#  'Jardim Sulacap' 'R. Bandeirantes' 'Higienópolis' 'São Conrado '
#  'Maria da Graça' 'Santo Cristo' 'Recreio dos Bandeirantes - Rj' 'Rocha'
#  'Freguesia - Jacarépaguá' 'Quintino Bocaiuva' 'Jacarepaguá' 'Gambôa'
#  'São Francisco Xavie' 'Praça Seca' 'Cidade de Deus' 'Penha'
#  'Praia de Boiçucanga' 'Tanque' 'Alto da Boa Vista'
#  'Esplanada do Cruzeiro' 'Bairro de Fátima' 'Campinho' 'Ribeira'
#  'Abolição' 'Jd Botanico' 'Padre Miguel' 'Benfica' 'B Tijuca'
#  'Engenho de Dentro' 'Vila da Penha' 'Alto Leblon/ Chácara do Céu'
#  'Rio de Janeiro Ilha do governador ' 'Rcr Bandeirantes' 'Barra Guaratiba'
#  'Bráz De Pina' 'RJ Jardim Guanabara' 'Meier' 'Recreio/RJ'
#  'Todos os Santos' 'Freguesia (Ilha do Governador)' 'Copacabvana'
#  'Rio de Janeiro, Rio de Janeiro, ' 'Praia do Recreio dos Bandeirantes'
#  'Jardim Carioca' 'Água Santa' 'Gloria' 'Pca da Bandeira'
#  'Complexo do Alemão' 'Tijuca/RJ' 'São Francisco Xavier' 'Campo Belo'
#  'Honório Gurgel' 'Redentor' 'Vasco da Gama' 'Recreio Bandeirante'
#  'Realengo' 'De Fátima' 'Grumari' 'Olaria' 'Cachambi' 'Vila Cosmos'
#  'Inhoaíba' 'Praia da Bandeira' 'Bento Ribeiro' 'Vicente de Carvalh'
#  'IPANEMA' 'Riocentro' 'Rio de Janeiro - Leblon' 'Rio de Janeiro, Ipanema'
#  'Rio De Janeiro,' 'Copacabana - Rio de Janeiro' 'Araras, Rio de Janeiro'
#  'Barra da Tijuca - Rio de Janeiro' 'Município do Rio de Janeiro -Buzios '
#  'Niterói' 'Cabo Frio ' 'Ipanema\nIpanema' 'realengo' 'Mangueira'
#  'Vicente de Carvalho' 'Angra dos Reis' 'Copacabana / RJ' 'Rio Janeiro'
#  'Guadalupe' 'Cascadura' 'Freguesia Jacarepagua'
#  'Praia do Pontal de Sernambetiba' 'Encantado' 'Parque Sao Nicolau'
#  'Camaçari ' 'Ilha do Governador' '1º etapa'
#  ' COPACABANA- Rio de Janeiro ' 'Cocotá' 'Oswaldo Cruz' 'Cacuia'
#  'Rocha Miranda' 'Ramos' 'Ilha das Cobras' 'Pilares' 'Rec dos Bandeirante'
#  'Copacaban' 'Recreio dos Bandeir' 'Copacapana' 'Río de janeiro '
#  'Copacabana/RJ' 'Inhoaiba' 'Cidade Universitária' 'Mangaratiba '
#  'Balneário Barra do Sul' 'Barra da tijuca' 'Barra de Guaratiba '
#  'Taquara - Jpa.' 'Rio de Jameiro' 'Praia de Maresias'
#  'R. dos Bandeirantes' 'Pc Bandeira' 'Río de Janeiro ' 'Higüey '
#  'Engenho da Rainha' 'Marechal Hermes' 'Rocinha' 'Váz Lobo'
#  'Copacabana - LEME' 'RIO DE JANEIRO ' 'Copacabana - RJ'
#  'Recreio dos Bandeirantes - RJ' 'Cordovil' 'Paraty' 'Barra Grande '
#  'Cabo Frio' 'Vila Militar' 'Joatinga, Rio de Janeiro' 'Teresopolis'
#  'São Francisco' 'Senador Vasconcelos' 'Tamoios Cabo Frio'
#  'Copacabana /Rio de Janeiro' 'Galeão' 'Senador Camará' 'São Paulo'
#  'Praia de Águas Belas' 'Guapimirim' 'Lapa' 'Pavuna' 'Bancários'
#  'Caldas Novas ' 'Piuma' 'Barros Filho' 'Costa Barros'
#  'Lins de Vasconcelo' 'Jacarepagua Freguesia ' 'Ri'
#  'Rio de Janeiro Barra da Tijuca' 'Botafogo - Rio de Janeiro' 'Andaraí'
#  'Maré' 'Glória / Santa Teresa' 'Rio de Janeiro / Copacabana' 'CopaCabana'
#  'Copacabana, RJ' 'Flamengo Rio de Janeiro'
#  'Vargem Grande, Rio de Janeiro ' 'Nova Iguaçu' 'Engenheiro Leal'
#  'I. Governador' 'Jardim America' 'Jacarépagua' 'Vigário Geral' 'Deodoro'
#  'Manguinhos' 'Brás de Pina' 'Méier' 'Bairro Botafogo'
#  'Rio de Janeiro, Copacabana' 'R dos Bandeirantes' 'Bertioga'
#  'Serrinha do Alambari ' 'Freguesia de Jacarepaguá' 'COPACABANA'
#  'Glória/centro ' 'Rio de Janeio' 'Arraial do Cabo' 'Grajaú' 'Coelho Neto'
#  'Tomás Coelho' 'São Conrado / Joa ' 'Rios de Janeiro' 'Santo Antônio'
#  'Itacoatiara' 'Jardim Pero' 'Foguete' 'Gloria ' 'Praia Grossa' 'Caborê'
#  'Itaipava ' 'Botafogo ' 'Gamboa' 'Colégio' 'Rio  de Janeiro' 'Jacaré'
#  'Cajueiro' 'Recreio dos Bandeirantes - Rio de Janeiro ' 'Pr Ferradura'
#  'Ilha Primeira' 'Guapemirim' 'Areal' 'Village da Ferradura' 'V Carvalho'
#  'Praia Linda' 'Taquara Jacarepaguá-RJ' 'Sítio' 'Rio de ianeiro ' 'Acari'
#  'E' 'Alta floresta ' 'Rio  de janeiro' 'Rio de  Janeiro ' 'Mury'
#  'Rio de Janeieo' 'Ricardo de Albuquerque'
#  'Cidade Universitária da Universidade Federal do Rio de Janeiro' 'Moneró'
#  'Centro, Bairro de Fátima' 'Recreiio' 'Copacabana, Rio de Janeiro, RJ'
#  'Fazenda Velha' 'Rio Centro ' 'Praia de Guaratiba ' 'Praça da Bandeira'
#  'Domingos Martins' 'Freguesia' 'Cidade Industrial' 'Rio de Janeiro RJ'
#  'Rio De Janeiro – Rj' 'Recreio Bendeirante' 'Recreio dos Bande'
#  'Praia da Urca' 'city' ' Barra da Tijuca' 'Vila Canaa' 'Vila Aparecida'
#  'Jardim Excelcior' 'rRio de Janeiro' 'Rio de Janeiro Angra dos Reis '
#  'Riio De Janeiro' 'Maracanã ' 'Armação dos Búzios' 'Balneário Camboriú '
#  'Nilópolis' 'R' 'Taquara ' 'Copacabana Rio de Janeiro ' 'leblon'
#  'Petrópolis ' 'Bom jardim' 'Río de Janeiro Copacabana ' 'COPACABANA '
#  'Jardim Esperança' 'CENTR0' 'Quintino Bocaiúva' 'Itaipava'
#  'Magalhães Bastos' 'Praia de Jericoacoara ' 'Parque Analândia' 'Jandira'
#  'Juiz de fora' 'Campo dos Afonsos' 'Parque Juriti' 'Hi' 'Duque De Caxias'
#  'Cabedelo' 'Guaramiranga' 'Praia Grande ' 'Cinelândia' 'Rio de Janeior'
#  'Villa de buzios,' 'Mucugê ' 'joatinga' 'Jardim do Mar' 'Jardim Del Rey'
#  'Terra Nova Uberlândia 1' 'Vila Assunção' 'Santana' 'Miguel Couto'
#  'Vila Sao Guilherme' 'Copacabana, Rio de Janeiro, BR']

# %% [markdown]
# #### Notas:
#
# + Coluna **neighbourhood** : Esta coluna recebe o valor inserido pelo anfitrião e depois é ajustada pelo airbnb na coluna **neighbourhood_cleansed** com isso irei eliminar a coluna neighbourhood e vou renomear a coluna neighbourhood_cleansed para neighbourhood
# + Coluna **smart_location**

# %%
#Usando API REST publica para obter os limites de bairros do rio de janeiro.

url_bairros = "https://pgeo3.rio.rj.gov.br/arcgis/rest/services/Cartografia/Limites_administrativos/MapServer/4/query?where=1=1&outFields=*&f=geojson"
bairros_rio = gpd.read_file(url_bairros)

print(bairros_rio.columns)
print(bairros_rio.head())
# Out:
# Index(['objectid', 'nome', 'regiao_adm', 'area_plane', 'codbairro', 'codra',
#        'codbnum', 'link', 'rp', 'cod_rp', 'codbairro_long', 'st_area(shape)',
#        'st_perimeter(shape)', 'geometry'],
#       dtype='object')
#    objectid            nome                regiao_adm area_plane codbairro  \
# 0       481         Grumari  BARRA DA TIJUCA                   4       133
# 1       402  Jardim Sulacap  REALENGO                          5       137
# 2       425           Saúde  PORTUARIA                         1       001
# 3       377        Vaz Lobo  MADUREIRA                         3       084
# 4       354         Ribeira  ILHA DO GOVERNADOR                3       091
#
#    codra  codbnum                                               link  \
# 0     24      133  Grumari                   &area=133           ...
# 1     33      137  Jardim Sulacap            &area=137           ...
# 2      1        1  Saúde                     &area=1             ...
# 3     15       84  Vaz Lobo                  &area=84            ...
# 4     20       91  Ribeira                   &area=91            ...
#
#                    rp cod_rp  codbairro_long  st_area(shape)  \
# 0     Barra da Tijuca    4.2             133    9.598851e+06
# 1               Bangu    5.1             137    7.869225e+06
# 2              Centro    1.1               1    3.638186e+05
# 3           Madureira    3.3              84    1.101224e+06
# 4  Ilha do Governador    3.7              91    8.619272e+05
#
#    st_perimeter(shape)                                           geometry
# 0         23375.374038  MULTIPOLYGON (((-43.50819 -23.03311, -43.50882...
# 1         14519.328424  POLYGON ((-43.37541 -22.88962, -43.37541 -22.8...
# 2          2646.220568  POLYGON ((-43.18115 -22.89543, -43.18119 -22.8...
# 3          5030.573927  POLYGON ((-43.32395 -22.85527, -43.32424 -22.8...
# 4          7050.041084  MULTIPOLYGON (((-43.16461 -22.82115, -43.16463...

# %%
# 1) Garante CRS e cria GeoDataFrame de pontos (lon, lat)
gdf_pts = gpd.GeoDataFrame(
    df_localizacao.copy(),
    geometry=gpd.points_from_xy(df_localizacao['longitude'], df_localizacao['latitude']),
    crs="EPSG:4326"
)

# 2) Garante que bairros_rio está no mesmo CRS
if bairros_rio.crs is None:
    bairros_rio = bairros_rio.set_crs("EPSG:4326")
elif bairros_rio.crs != gdf_pts.crs:
    bairros_rio = bairros_rio.to_crs(gdf_pts.crs)

# 3) sjoin (ponto dentro do polígono do bairro)
gjoined = gpd.sjoin(
    gdf_pts,
    bairros_rio[['nome', 'regiao_adm', 'rp', 'geometry']],  # pegue só o que precisa
    how="left",
    predicate="within"
).drop(columns=['index_right'])

# %%
# Padronização de campos

def title_pt(s: pd.Series) -> pd.Series:
    def fix(x):
        if not isinstance(x, str): return x
        t = x.title()
        for a,b in [(" De "," de "),(" Da "," da "),(" Do "," do "),
                    (" Dos "," dos "),(" Das "," das "),(" Em "," em "),(" E "," e ")]:
            t = t.replace(a,b)
        return t.strip()
    return s.apply(fix)

# Bairro oficial
gjoined['neighbourhood_cleansed'] = title_pt(gjoined['nome'])

# City e Market: se caiu em bairro do RJ → “Rio de Janeiro”
gjoined['city'] = gjoined['city'].where(gjoined['neighbourhood_cleansed'].isna(), 'Rio de Janeiro')
gjoined['market'] = gjoined['market'].where(gjoined['neighbourhood_cleansed'].isna(), 'Rio de Janeiro')

# Country (corrige scrapes errados tipo “Andorra”)
gjoined['country_code'] = gjoined.get('country_code', pd.Series(index=gjoined.index))
gjoined['country'] = gjoined.get('country', pd.Series(index=gjoined.index))
gjoined.loc[gjoined['city'].eq('Rio de Janeiro'), ['country_code','country']] = ['BR','Brazil']

# Fallback por bbox do Brasil (opcional)
mask_bbox_br = gjoined['longitude'].between(-74, -34) & gjoined['latitude'].between(-34, 5)
gjoined.loc[mask_bbox_br, ['country_code','country']] = ['BR','Brazil']

# smart_location = "Cidade, País"
gjoined['smart_location'] = (
    title_pt(gjoined['city']).fillna('') + ', ' + title_pt(gjoined['country']).fillna('')
).str.strip(', ')

# Padroniza capitalização
gjoined['city'] = title_pt(gjoined['city'])
gjoined['market'] = title_pt(gjoined['market'])

# %%
# Remove geometria para voltar a DataFrame “puro”
df_localizacao_silver = pd.DataFrame(gjoined.drop(columns='geometry'))

log_geo = {
    "pct_bairro_atribuido": round(df_localizacao_silver['neighbourhood_cleansed'].notna().mean()*100, 2),
    "pct_city_atribuido": round(df_localizacao_silver['city'].notna().mean()*100, 2),
    "corrigidos_para_BR": int(((df_localizacao_silver['country_code'] == 'BR') & (df_localizacao.get('country_code') != 'BR')).sum()),
    "total_linhas": len(df_localizacao_silver),
}
print(log_geo)
# Out:
# {'pct_bairro_atribuido': np.float64(99.96), 'pct_city_atribuido': np.float64(100.0), 'corrigidos_para_BR': 31, 'total_linhas': 902210}

# %%
df_localizacao_silver.head()
# Out:
#    id_localizacao  fk_anuncio                                  street  \
# 0               1       14063              Rio de Janeiro, RJ, Brazil
# 1               2       17878  Rio de Janeiro, Rio de Janeiro, Brazil
# 2               3       24480  Rio de Janeiro, Rio de Janeiro, Brazil
# 3               4       25026  Rio de Janeiro, Rio de Janeiro, Brazil
# 4               5       31560              Rio de Janeiro, RJ, Brazil
#
#   neighbourhood neighbourhood_cleansed            city           state  \
# 0      Botafogo               Botafogo  Rio de Janeiro              RJ
# 1    Copacabana             Copacabana  Rio de Janeiro  Rio de Janeiro
# 2       Ipanema                Ipanema  Rio de Janeiro  Rio de Janeiro
# 3    Copacabana             Copacabana  Rio de Janeiro  Rio de Janeiro
# 4       Ipanema                Ipanema  Rio de Janeiro              RJ
#
#      zipcode          market          smart_location country_code country  \
# 0  22250-040  Rio de Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 1  22020-050  Rio de Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 2  22411-010  Rio de Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 3  22060-020  Rio de Janeiro  Rio de Janeiro, Brazil           BR  Brazil
# 4  22410-003  Rio de Janeiro  Rio de Janeiro, Brazil           BR  Brazil
#
#     latitude  longitude is_location_exact        nome  \
# 0 -22.946854 -43.182737                 t    Botafogo
# 1 -22.965919 -43.178962                 t  Copacabana
# 2 -22.985698 -43.201935                 t     Ipanema
# 3 -22.977117 -43.190454                 t  Copacabana
# 4 -22.983024 -43.214270                 t     Ipanema
#
#                  regiao_adm        rp
# 0  BOTAFOGO                  Zona Sul
# 1  COPACABANA                Zona Sul
# 2  LAGOA                     Zona Sul
# 3  COPACABANA                Zona Sul
# 4  LAGOA                     Zona Sul

# %%
df_localizacao_silver['market'].value_counts()
# Out:
# market
# Rio de Janeiro           902208
# Other (International)         2
# Name: count, dtype: int64

# %%
#Removendo dois valores que nao conseguimos mapear com o geopandas
df_localizacao_silver = df_localizacao_silver[df_localizacao_silver['market'] != 'Other (International)']

# %%
df_localizacao_silver.drop(columns=['neighbourhood','neighbourhood_cleansed'], inplace=True)
df_localizacao_silver.rename(columns={'nome': 'neighbourhood'}, inplace=True)

# %%
#Definicao de pontos turisticos
pois = pd.DataFrame({
    'poi': [
        'Cristo Redentor','Pao de Acucar','Praia de Copacabana','Praia de Ipanema',
        'Maracana','Arcos da Lapa','Museu do Amanha','Jardim Botanico'
    ],
    'lat': [-22.951916, -22.948611, -22.971177, -22.986869, -22.912161, -22.912167, -22.895911, -22.968801],
    'lon': [-43.210487, -43.156389, -43.182543, -43.155444, -43.230184, -43.179954, -43.180763, -43.223593]
})


gdf_pts = gpd.GeoDataFrame(
    df_localizacao_silver.copy(),
    geometry=gpd.points_from_xy(df_localizacao_silver['longitude'], df_localizacao_silver['latitude']),
    crs="EPSG:4326"
)

gdf_pois = gpd.GeoDataFrame(
    pois.copy(),
    geometry=gpd.points_from_xy(pois['lon'], pois['lat']),
    crs="EPSG:4326"
)

# Projeta para metros (UTM 23S)
gdf_pts_m = gdf_pts.to_crs(31983)
gdf_pois_m = gdf_pois.to_crs(31983)

# Distância para cada POI em km
for _, r in gdf_pois_m.iterrows():
    col = f"dist_{r['poi'].lower().replace(' ','_')}_km"
    gdf_pts_m[col] = gdf_pts_m.geometry.distance(r.geometry) / 1000.0

# POI mais próximo (usando as colunas calculadas)
dist_cols = [c for c in gdf_pts_m.columns if c.startswith('dist_') and c.endswith('_km')]
gdf_pts_m['nearest_poi_km'] = gdf_pts_m[dist_cols].min(axis=1)
gdf_pts_m['nearest_poi_name'] = gdf_pts_m[dist_cols].idxmin(axis=1).str.replace(r'^dist_|_km$', '', regex=True)

# Volta a DF se quiser
df_localizacao_silver = pd.DataFrame(gdf_pts_m.drop(columns='geometry'))

# %%
df_localizacao_silver.head(5)
# Out:
#    id_localizacao  fk_anuncio                                  street  \
# 0               1       14063              Rio de Janeiro, RJ, Brazil
# 1               2       17878  Rio de Janeiro, Rio de Janeiro, Brazil
# 2               3       24480  Rio de Janeiro, Rio de Janeiro, Brazil
# 3               4       25026  Rio de Janeiro, Rio de Janeiro, Brazil
# 4               5       31560              Rio de Janeiro, RJ, Brazil
#
#              city           state    zipcode          market  \
# 0  Rio de Janeiro              RJ  22250-040  Rio de Janeiro
# 1  Rio de Janeiro  Rio de Janeiro  22020-050  Rio de Janeiro
# 2  Rio de Janeiro  Rio de Janeiro  22411-010  Rio de Janeiro
# 3  Rio de Janeiro  Rio de Janeiro  22060-020  Rio de Janeiro
# 4  Rio de Janeiro              RJ  22410-003  Rio de Janeiro
#
#            smart_location country_code country  ...  dist_cristo_redentor_km  \
# 0  Rio de Janeiro, Brazil           BR  Brazil  ...                 2.900808
# 1  Rio de Janeiro, Brazil           BR  Brazil  ...                 3.585761
# 2  Rio de Janeiro, Brazil           BR  Brazil  ...                 3.842621
# 3  Rio de Janeiro, Brazil           BR  Brazil  ...                 3.465510
# 4  Rio de Janeiro, Brazil           BR  Brazil  ...                 3.466836
#
#    dist_pao_de_acucar_km dist_praia_de_copacabana_km dist_praia_de_ipanema_km  \
# 0               2.709394                    2.693764                 5.241443
# 1               3.005603                    0.688432                 3.346509
# 2               6.219783                    2.557381                 4.768766
# 3               4.708603                    1.044435                 3.748849
# 4               7.053931                    3.507942                 6.046838
#
#   dist_maracana_km dist_arcos_da_lapa_km  dist_museu_do_amanha_km  \
# 0         6.200742              3.852050                 5.645376
# 1         7.940186              5.953718                 7.755335
# 2         8.643863              8.449579                10.177916
# 3         8.267550              7.273149                 9.048024
# 4         8.015621              8.600274                10.241277
#
#    dist_jardim_botanico_km  nearest_poi_km     nearest_poi_name
# 0                 4.843959        2.693764  praia_de_copacabana
# 1                 4.587990        0.688432  praia_de_copacabana
# 2                 2.904091        2.557381  praia_de_copacabana
# 3                 3.520814        1.044435  praia_de_copacabana
# 4                 1.842540        1.842540      jardim_botanico
#
# [5 rows x 26 columns]

# %% [markdown]
# ### **Tratamento tabela T_DIM_PROPRIEDADE**

# %%
#Leitura da tabela propriedade
df_propriedade = pd.read_sql('SELECT * FROM a_bronze. "T_DIM_PROPRIEDADE"',conn)

# %%
df_propriedade
# Out:
#         id_propriedade  fk_anuncio property_type        room_type  \
# 0                    1       14063     Apartment  Entire home/apt
# 1                    2       17878   Condominium  Entire home/apt
# 2                    3       24480     Apartment  Entire home/apt
# 3                    4       25026     Apartment  Entire home/apt
# 4                    5       31560     Apartment  Entire home/apt
# ...                ...         ...           ...              ...
# 902205          902206    38844730     Apartment  Entire home/apt
# 902206          902207    38846408     Apartment  Entire home/apt
# 902207          902208    38846703     Apartment  Entire home/apt
# 902208          902209    38847050     Apartment  Entire home/apt
# 902209          902210    38847655     Apartment     Private room
#
#         accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0                  4        1.0       0.0   2.0  Real Bed
# 1                  5        1.0       2.0   2.0  Real Bed
# 2                  2        1.0       1.0   1.0  Real Bed
# 3                  3        1.0       1.0   2.0  Real Bed
# 4                  3        1.0       1.0   2.0  Real Bed
# ...              ...        ...       ...   ...       ...
# 902205             4        1.0       0.0   2.0  Real Bed
# 902206             4        2.0       2.0   3.0  Real Bed
# 902207             5        1.0       1.0   2.0  Real Bed
# 902208             4        1.0       1.0   1.0  Real Bed
# 902209             2        0.0       1.0   1.0  Real Bed
#
#                                                 amenities  minimum_nights  \
# 0       {TV,Internet,"Air conditioning",Kitchen,Doorma...            60.0
# 1       {TV,"Cable TV",Internet,Wifi,"Air conditioning...             4.0
# 2       {TV,"Cable TV",Wifi,"Air conditioning","First ...             3.0
# 3       {TV,"Cable TV",Internet,Wifi,"Air conditioning...             4.0
# 4       {TV,"Cable TV",Internet,Wifi,"Air conditioning...             2.0
# ...                                                   ...             ...
# 902205  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...             1.0
# 902206  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...             2.0
# 902207  {TV,Wifi,"Air conditioning",Kitchen,Elevator,W...             3.0
# 902208  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...             1.0
# 902209  {TV,Kitchen,"Free parking on premises","Smokin...             1.0
#
#         maximum_nights calendar_updated has_availability  availability_30  \
# 0                365.0      7 weeks ago                t             28.0
# 1                 90.0        yesterday                t             11.0
# 2                 90.0      5 weeks ago                t              0.0
# 3                 30.0            today                t             28.0
# 4               1125.0      5 weeks ago                t             15.0
# ...                ...              ...              ...              ...
# 902205          1125.0            today                t             16.0
# 902206          1125.0            today                t             23.0
# 902207          1125.0            today                t             30.0
# 902208          1125.0            today                t             17.0
# 902209            30.0            today                t             27.0
#
#         availability_60  availability_90  availability_365
# 0                  58.0             88.0             363.0
# 1                  29.0             58.0             286.0
# 2                   0.0              0.0               0.0
# 3                  58.0             88.0             363.0
# 4                  45.0             75.0             345.0
# ...                 ...              ...               ...
# 902205             46.0             76.0             351.0
# 902206             53.0             83.0              83.0
# 902207             60.0             90.0             365.0
# 902208             47.0             77.0              77.0
# 902209             57.0             87.0             177.0
#
# [902210 rows x 18 columns]

# %% [markdown]
# #### Notas:
#
# + Coluna: **"beds"** faz sentido ser um valor decimal, sendo 1.5 = um banheiro + lavabo
#
# + Conlunas **"bathrooms", "bedrooms", "minimum_nights", "maximum_nights", "calendar_updated", "availability_30","availability_60", "availability_90", "availability_365"**: Estão como float porem devem ser numeros inteiros
